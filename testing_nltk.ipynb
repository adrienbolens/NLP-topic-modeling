# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import urllib.request
response_urllib = urllib.request.urlopen('https://en.wikipedia.org/wiki/SpaceX')
html = response_urllib.read()

import requests
response = requests.get('https://en.wikipedia.org/wiki/SpaceX')

# %%
print(response_urllib)
print(response)
# Out:
# ...
# <Response [200]>

# %%
html[:50]
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en'

# %%
response._content[:50]
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en'

# %%
response.text[:50]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en'

# %%
print(response.__dict__.keys())
print(type(response).__dict__.keys())
# Out:
# dict_keys(['_content', '_content_consumed', '_next', 'status_code', 'headers', 'raw', 'url', 'encoding', 'history', 'reason', 'cookies', 'elapsed', 'request', 'connection'])
# dict_keys(['__module__', '__doc__', '__attrs__', '__init__', '__enter__', '__exit__', '__getstate__', '__setstate__', '__repr__', '__bool__', '__nonzero__', '__iter__', 'ok', 'is_redirect', 'is_permanent_redirect', 'next', 'apparent_encoding', 'iter_content', 'iter_lines', 'content', 'text', 'json', 'links', 'raise_for_status', 'close', '__dict__', '__weakref__'])

# %%
from bs4 import BeautifulSoup
soup_urllib = BeautifulSoup(html,'html5lib')
text = soup.get_text(strip = True)

# %%
# with open('filename') as html_1:
#     soup_1 = BeautifulSoup(html_1, 'html5lib')

# %%
soup = BeautifulSoup(response.text, 'html5lib')

# %%
print(soup_urllib.prettify()[:100])
print(100*'=')
print(f'{"":*^100}')
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <
# ...
# ****************************************************************************************************
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    SpaceX - Wikipedia
#   </title>
#   <script>
# ...

# %%
soup.__dict__.keys()
# Out:
# dict_keys(['builder', 'is_xml', 'known_xml', '_namespaces', 'parse_only', 'markup', 'original_encoding', 'declared_html_encoding', 'contains_replacement_characters', 'parser_class', 'name', 'namespace', 'prefix', 'preserve_whitespace_tags', 'attrs', 'contents', 'parent', 'previous_element', 'next_element', 'next_sibling', 'previous_sibling', 'hidden', 'can_be_empty_element', 'current_data', 'currentTag', 'tagStack', 'preserve_whitespace_tag_stack', '_most_recent_element'])

# %%
print(soup.title)
print(soup.title.text)
# Out:
# <title>SpaceX - Wikipedia</title>
# SpaceX - Wikipedia

# %%
tokens = [t for t in text.split()]
# print(tokens)

# %%
import nltk
from nltk.corpus import stopwords
sr = stopwords.words('english')
clean_tokens = tokens[:]
for token in tokens:
    if token in stopwords.words('english'):
        clean_tokens.remove(token)
        
freq = nltk.FreqDist(clean_tokens)
for key,val in freq.items():
    print(str(key) + ':' + str(val))
# Out:
# SpaceX:163
# -:6
# Wikipediadocument.documentElement.className=document.documentElement.className.replace(/(^|\s)client-nojs(\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"SpaceX","wgTitle":"SpaceX","wgCurRevisionId":909906020,"wgRevisionId":909906020,"wgArticleId":832774,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1:1
# maint::15
# BOT::12
# original-url:12
# status:12
# unknown","CS1:1
# Unfit:3
# url","CS1:1
# French-language:2
# sources:3
# (fr)","Articles:1
# short:4
# description","Use:1
# American:6
# English:2
# November:16
# 2015","All:1
# Wikipedia:4
# articles:28
# written:2
# English","Use:1
# mdy:2
# dates:2
# 2015","Coordinates:1
# Wikidata","Pages:1
# using:13
# infobox:2
# company:32
# trading:2
# name","Articles:1
# containing:14
# potentially:14
# dated:14
# statements:14
# 2017","All:1
# statements","Articles:2
# ...

# %%
freq.plot(20, cumulative=False)
